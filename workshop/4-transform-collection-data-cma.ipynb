# %%
from IPython.core.display import HTML

# %% [markdown]
# #  Collections Data to Linked Art - Cleveland Museum of Art
#
# This Jupyter notebook transforms collection data from the Cleveland Museum of Art to a Linked Art representation in a JSON-LD format.
#
# ## Collection Data
#
# The input data file is available from the Cleveland Museum of Art's GitHub repository:
# https://github.com/ClevelandMuseumArt/openaccess
#
# ## Transformation Process
#
# 1. Read CSV file
# 2. Convert CSV file to Python Dictionary
# 3. Create a field mapping between the CSV file fields and the Linked Art data model
# 4. Create an object property dictionary

# %%
try:
    import IPython
except:
    # %pip install IPython
    import IPython   
    
from IPython.display import display,IFrame,HTML, Javascript
 
try:
    import json
except:
    # %pip install json
    import json 
  
try:
    import csv
except:
    # %pip install csv
    import csv
    
import os

try:
    import cromulent 
except:
    # %pip install cromulent
    import cromulent

from cromulent.model import factory
    
import lib.linkedart as la 

try:
    import pandas as pd
except:
    # %pip install pandas
    import pandas as pd

# %% [markdown]
# ### Parse Collection Data CSV File

# %%
file = './data/example/cma.csv'
mpg = pd.read_csv(file,low_memory=False)
mpg.head()
# Out:
#       id  accession_number share_license_status  \
# 0  74570          2018.410                  CC0
# 1  74572          2018.420                  CC0
# 2  74576          2015.446                  CC0
# 3  74580          2018.430                  CC0
# 4  74581          2018.440                  CC0
#
#                                            tombstone  current_location  \
# 0  Profile Portrait of a Man, 18th century. Attri...               NaN
# 1  The Temptation of St. Anthony, 19th century. J...               NaN
# 2  The Pipes of Pan, 1865. Mariano Fortuny (Spani...               NaN
# 3  Costume Study, before 1852. Henri Lehmann (Fre...               NaN
# 4  Nude Study of an Old Man, before 1852. Henri L...               NaN
#
#                            title  title_in_original_language  series  \
# 0      Profile Portrait of a Man                         NaN     NaN
# 1  The Temptation of St. Anthony                         NaN     NaN
# 2               The Pipes of Pan                         NaN     NaN
# 3                  Costume Study                         NaN     NaN
# 4       Nude Study of an Old Man                         NaN     NaN
#
#    series_in_original_language creation_date  ...  \
# 0                          NaN  18th century  ...
# 1                          NaN  19th century  ...
# 2                          NaN          1865  ...
# 3                          NaN   before 1852  ...
# 4                          NaN   before 1852  ...
#
#                                  digital_description  wall_description  \
# 0  This portrait bust is a counterproof: the reve...               NaN
# 1  Boilly’s scene represents the Temptations of S...               NaN
# 2                                                NaN               NaN
# 3  Lehmann’s drawing belongs to a pair in which t...               NaN
# 4  In preparation for executing largescale painti...               NaN
#
#                                   external_resources  \
# 0  {'wikidata': [], 'internet_archive': ['https:/...
# 1           {'wikidata': [], 'internet_archive': []}
# 2           {'wikidata': [], 'internet_archive': []}
# 3           {'wikidata': [], 'internet_archive': []}
# 4           {'wikidata': [], 'internet_archive': []}
#
#                                            citations catalogue_raisonne  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Lehmann, Henri, and Marie-Madeleine Aubrun. He...                NaN
# 4  Lehmann, Henri, and Marie-Madeleine Aubrun. He...                NaN
#
#                                      url  \
# 0   https://clevelandart.org/art/2018.41
# 1   https://clevelandart.org/art/2018.42
# 2  https://clevelandart.org/art/2015.446
# 3   https://clevelandart.org/art/2018.43
# 4   https://clevelandart.org/art/2018.44
#
#                                            image_web  \
# 0  https://openaccess-cdn.clevelandart.org/2018.4...
# 1  https://openaccess-cdn.clevelandart.org/2018.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                                          image_print  \
# 0  https://openaccess-cdn.clevelandart.org/2018.4...
# 1  https://openaccess-cdn.clevelandart.org/2018.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                                           image_full  \
# 0  https://openaccess-cdn.clevelandart.org/2018.4...
# 1  https://openaccess-cdn.clevelandart.org/2018.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                    updated_at
# 0  2021-06-29 06:35:50.582000
# 1  2020-11-04 19:07:40.307000
# 2  2021-01-05 10:00:05.748000
# 3  2021-03-27 12:12:37.772000
# 4  2021-03-27 12:12:37.779000
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Read Collection Data CSV file into Python Dictionary
#
# - Remove Byte Order Mark (BOM) from CSV file
# - Use `csv.DictReader()` to create an object that operates like a regular reader but maps the information in each row to a dict whose keys are given by the optional fieldnames parameter.

# %%
# remove BOM see - https://stackoverflow.com/questions/8898294/convert-utf-8-with-bom-to-utf-8-with-no-bom-in-python
s = open(file, mode='r', encoding='utf-8-sig').read()
open(file, mode='w', encoding='utf-8').write(s)

# open file and read into Python dictionary
allObjects = csv.DictReader(open(file, mode='r',encoding='utf-8'))

display(HTML("<H3>Example Record in Python Dictionary</H3>"))
for obj in allObjects:
    print(json.dumps(obj,indent=2))
    break
# Out:
# <H3>Example Record in Python Dictionary</H3>
# {
#   "id": "74570",
#   "accession_number": "2018.41",
#   "share_license_status": "CC0",
#   "tombstone": "Profile Portrait of a Man, 18th century. Attributed to Louis Rolland Trinquesse (French, c. 1746\u2013c. 1800). Black chalk counterproof; sheet: 20.3 x 17.5 cm (8 x 6 7/8 in.). The Cleveland Museum of Art, Bequest of Muriel Butkin 2018.41",
#   "current_location": "",
#   "title": "Profile Portrait of a Man",
#   "title_in_original_language": "",
#   "series": "",
#   "series_in_original_language": "",
#   "creation_date": "18th century",
#   "creation_date_earliest": "1800",
#   "creation_date_latest": "1899",
#   "creators": "Louis Rolland Trinquesse (French, c. 1746\u2013c. 1800), artist",
#   "culture": "France, 19th century",
#   "technique": "Black chalk counterproof",
#   "support_materials": "",
#   "department": "Drawings",
#   "collection": "DR - French",
#   "type": "Drawing",
#   "measurements": "Sheet: 20.3 x 17.5 cm (8 x 6 7/8 in.)",
#   "state_of_the_work": "",
#   "edition_of_the_work": "",
#   "creditline": "Bequest of Muriel Butkin",
#   "copyright": "",
#   "inscriptions": "verso: lower right corner, in graphite: 798; mount, lower right, in graphite: Contre \u00e9precue; verso of mount: center, in graphite: 798 / Ctm Epr. Trinquesse; upper left corner, in graphite: trinquess\u00e9; Countermark: center: J Honig / & / Zoonen; framer\u2019s sticker: R. Charpentier/ 104.Ba Haussmann/ Paris",
#   "exhibitions": "",
#   "provenance": "",
#   "find_spot": "",
#   "related_works": "",
#   "former_accession_numbers": "[]",
#   "fun_fact": "",
#   "digital_description": "This portrait bust is a counterproof: the reverse image of a composition, made by placing blank paper on top of a drawing and transferring the design with pressure. Eighteenth-century artists frequently made counterproofs of their drawings to replicate their work. This process also enabled them to experience how their images would appear if they were reproduced as prints.",
#   "wall_description": "",
#   "external_resources": "{'wikidata': [], 'internet_archive': ['https://archive.org/details/clevelandart-2018.41-profile-portrait-of']}",
#   "citations": "",
#   "catalogue_raisonne": "",
#   "url": "https://clevelandart.org/art/2018.41",
#   "image_web": "https://openaccess-cdn.clevelandart.org/2018.41/2018.41_web.jpg",
#   "image_print": "https://openaccess-cdn.clevelandart.org/2018.41/2018.41_print.jpg",
#   "image_full": "https://openaccess-cdn.clevelandart.org/2018.41/2018.41_full.tif",
#   "updated_at": "2021-06-29 06:35:50.582000"
# }

# %% [markdown]
# #### Further Reading
#
# - Python CSV https://docs.python.org/3/library/csv.html
# - Byte Order Mark https://en.wikipedia.org/wiki/Byte_order_mark

# %% [markdown]
# ### Create field mapping

# %%
mapp =  {
    "id":"id",
    "accession_number":"accession_number",
    "accession_date": "",
    "classification" : "type",
    "title": "title",
    "alt_title": "title_in_original_language",
    "notes": "tombstone",
    "date_created":"creation_date",
    "date_created_earliest": "creation_date_earliest",
    "date_created_latest": "creation_date_latest",
    "created_period":"culture",
    "created_dynasty":"",
    "created_inscriptions":"inscriptions",
    "created_notes": "fun_fact",
    "creator":"creators",
    "physical_medium": "Medium",
    "physical_style": "",
    "physical_technique": "technique",
    "physical_description": "",
    "physical_dimensions": "measurements",
    "created_provenance": "provenance" ,
    "credit_line": "creditline",
    "collection" : "department",
    "current_status" : "current_location",
    "current_location": "current_location",
    "homepage": "url"
    
}

# %% [markdown]
# ### Create object property dictionary

# %%
def createObjProp(obj,mapp):
    objProp = {}
    csv_keys = list(obj.keys())
    for key in csv_keys:
        for prop in mapp:
            if key == mapp[prop]:
                if prop == "creator":
                    objProp[prop] = {"name": obj[key]}
                else:
                    objProp[prop] = obj[key]
    
    objProp["current_owner"] = {"name":"Cleveland Museum of Art",
                                "location":"Cleveland,Ohio",
                                "type": "http://vocab.getty.edu/aat/300312281" ,
                                "type_label": ""}
    return objProp


#  baseURI for JSON-LD document
baseURI = "https://clevelandart.org/art/"


for index,obj in enumerate(allObjects):
    if index >= 5:
        break
    objProp = createObjProp(obj,mapp)
    id = obj[mapp.get("id")]
    object_uri = baseURI + id
    
    objLA = None
    objLA = la.createObjDesc(objProp,la.objTypes,object_uri)
    # write to file 
    text_file = open("./data/example/cma/" + id + ".json", "wt")
    n = text_file.write(factory.toString(objLA, compact=False))
    text_file.close()

# %%
from IPython.display import display,HTML,Javascript
HTML('<h1>Data Visualisation</h1><div id="example" style="width:3000px;height:100%"/>')
# Out:
# <h1>Data Visualisation</h1><div id="example" style="width:3000px;height:100%"/>

# %%
from IPython.core.display import Javascript

code2 = "var file = './data/example/cma/" + id + ".json';"\
        "var selector = '#example';" \
        "visjsonld(file, selector); "  

with open('../src/js/visld.js', 'r') as _jscript:
    code = _jscript.read() + code2
Javascript(code)

# %%
from IPython.core.display import Javascript, HTML


def fn(fpath):       # 1.Get file names from directory
    file_list=os.listdir(r"" + fpath)
    cnt =1 
    for file in file_list:
        cnt = cnt+1
        
        display(HTML("<a target='_new' href='" + fpath + file + "'>" + file + "</a>"))


display(HTML("<h1>File list</h1><p>Click on a link to view created Linked Art JSON-LD file</p>"))
    
fn("./data/example/cma/")
# Out:
# <h1>File list</h1><p>Click on a link to view created Linked Art JSON-LD file</p>
# <a target='_new' href='./data/example/cma/74572.json'>74572.json</a>
# <a target='_new' href='./data/example/cma/74590.json'>74590.json</a>
# <a target='_new' href='./data/example/cma/74581.json'>74581.json</a>
# <a target='_new' href='./data/example/cma/74580.json'>74580.json</a>
# <a target='_new' href='./data/example/cma/74576.json'>74576.json</a>
# <a target='_new' href='./data/example/cma/74584.json'>74584.json</a>
