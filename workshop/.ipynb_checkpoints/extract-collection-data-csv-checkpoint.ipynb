# %% [markdown]
# # Extract Collection Data - CSV
#
# This notebook shows how to read in collection data in CSV format and convert it to a Python dictionary, ready for transformation to Linked Art
#
# Steps in this notebook:
# 1. Read CSV file
# 2. Convert CSV file to Python Dictionary

# %% [markdown]
# # Python modules
#
#
# Three Python modules will be used:
# * pandas
# * json
# * csv
#
# ## pandas
# https://pandas.pydata.org/
#
# <pre>"pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language."</pre>
#
# `pandas` is used to read in the csv file contents to a pandas dataframe for further processing in Python. A dataframe is a data structure to hold <pre>"two-dimensional, size-mutable, potentially heterogeneous tabular data."</pre>
#
#
# ## json
#
#
# The Python `json` module is used to encode and decode JSON objects and is used in the script to encode JSON objects before printing.
#
#
# ## csv
#
#
# <pre>The csv module implements classes to read and write tabular data in CSV format.</pre>
#
#
# ### Further Reading
# * https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#
# * https://docs.python.org/3/library/json.html
#
# * https://docs.python.org/3/library/csv.htm

# %%
# https://pandas.pydata.org/

try:
    import pandas as pd
except:
    # %pip install pandas
    import pandas as pd


try:
    import json
except:
    # %pip install json
    import json 
  
try:
    import csv
except:
    # %pip install csv
    import csv

# %% [markdown]
# ## Read CSV file contents using pandas
#
# The following code demonstrates how to read CSV into a pandas dataframe

# %%
file = '../data/cma/input/data.csv'
mpg = pd.read_csv(file,low_memory=False)

# %% [markdown]
# ### Print first 5 rows
# Print the first 5 rows for illustration

# %%
mpg.head()
# Out:
#       id accession_number share_license_status  \
# 0  74539         2015.449                  CC0
# 1  74540         2015.451                  CC0
# 2  74554         2015.447                  CC0
# 3  74570          2018.41                  CC0
# 4  74572          2018.42                  CC0
#
#                                            tombstone current_location  \
# 0  A Miller's Carriage, c. 1895. Albert-Charles L...              NaN
# 1  Leda and the Swan. Adolphe Yvon (French, 1817-...              NaN
# 2  Un Borreau (An Executioner), c. 1848. Auguste ...              NaN
# 3  Profile Portrait of a Man, 18th century. Attri...              NaN
# 4  The Temptation of St. Anthony, 19th century. J...              NaN
#
#                            title title_in_original_language series  \
# 0            A Miller's Carriage                        NaN    NaN
# 1              Leda and the Swan                        NaN    NaN
# 2    Un Borreau (An Executioner)                        NaN    NaN
# 3      Profile Portrait of a Man                        NaN    NaN
# 4  The Temptation of St. Anthony                        NaN    NaN
#
#   series_in_original_language creation_date  ...  \
# 0                         NaN       c. 1895  ...
# 1                         NaN           NaN  ...
# 2                         NaN       c. 1848  ...
# 3                         NaN  18th century  ...
# 4                         NaN  19th century  ...
#
#                                  digital_description  wall_description  \
# 0                                                NaN               NaN
# 1  In the late 1520s Michelangelo made a painting...               NaN
# 2                                                NaN               NaN
# 3  This portrait bust is a counterproof: the reve...               NaN
# 4  Boilly’s scene represents the Temptations of S...               NaN
#
#                                   external_resources citations  \
# 0  {'wikidata': [], 'internet_archive': ['https:/...       NaN
# 1           {'wikidata': [], 'internet_archive': []}       NaN
# 2           {'wikidata': [], 'internet_archive': []}       NaN
# 3  {'wikidata': [], 'internet_archive': ['https:/...       NaN
# 4           {'wikidata': [], 'internet_archive': []}       NaN
#
#   catalogue_raisonne                                    url  \
# 0                NaN  https://clevelandart.org/art/2015.449
# 1                NaN  https://clevelandart.org/art/2015.451
# 2                NaN  https://clevelandart.org/art/2015.447
# 3                NaN   https://clevelandart.org/art/2018.41
# 4                NaN   https://clevelandart.org/art/2018.42
#
#                                            image_web  \
# 0  https://openaccess-cdn.clevelandart.org/2015.4...
# 1  https://openaccess-cdn.clevelandart.org/2015.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                                          image_print  \
# 0  https://openaccess-cdn.clevelandart.org/2015.4...
# 1  https://openaccess-cdn.clevelandart.org/2015.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                                           image_full  \
# 0  https://openaccess-cdn.clevelandart.org/2015.4...
# 1  https://openaccess-cdn.clevelandart.org/2015.4...
# 2  https://openaccess-cdn.clevelandart.org/2015.4...
# 3  https://openaccess-cdn.clevelandart.org/2018.4...
# 4  https://openaccess-cdn.clevelandart.org/2018.4...
#
#                    updated_at
# 0  2021-06-29 06:35:50.572000
# 1  2020-11-04 19:07:39.161000
# 2  2021-03-27 12:12:37.752000
# 3  2021-06-29 06:35:50.582000
# 4  2020-11-04 19:07:40.307000
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Read CSV file contents using csv
#
# The following code demonstrates how to read in CSV file data using the `csv` module.
#
#
# ### Remove Byte Order Mark (BOM) from CSV file
#
# An initial step is shown, which is to remove Byte Order Marks (BOM) from the CSV file before loading it into a Python dictionary. See https://stackoverflow.com/questions/8898294/convert-utf-8-with-bom-to-utf-8-with-no-bom-in-python

# %%
# remove BOM

# open file 
s = open(file, mode='r', encoding='utf-8-sig').read()


# write to file 
open(file, mode='w', encoding='utf-8').write(s)
# Out:
# 80557121

# %% [markdown]
# ### Read CSV contents into Python dictionary
#
# Use `csv.DictReader()` to create a Python dictionary whose keys are the field names.

# %%
# open file and read into Python dictionary
allObjects = csv.DictReader(open(file, mode='r',encoding='utf-8'))

# %% [markdown]
# ### Print first `row` in dictionary
# Print first `row` in dictionary for illustration

# %%
for obj in allObjects:
    print(json.dumps(obj,indent=2))
    break
# Out:
# {
#   "id": "74539",
#   "accession_number": "2015.449",
#   "share_license_status": "CC0",
#   "tombstone": "A Miller's Carriage, c. 1895. Albert-Charles Lebourg (French, 1849-1928). Black and white chalk with stumping ; sheet: 33.2 x 49.7 cm (13 1/16 x 19 9/16 in.). The Cleveland Museum of Art, Bequest of Muriel Butkin 2015.449",
#   "current_location": "",
#   "title": "A Miller's Carriage",
#   "title_in_original_language": "",
#   "series": "",
#   "series_in_original_language": "",
#   "creation_date": "c. 1895",
#   "creation_date_earliest": "1890",
#   "creation_date_latest": "1900",
#   "creators": "Albert-Charles Lebourg (French, 1849-1928), artist",
#   "culture": "France, 19th-20th century",
#   "technique": "Black and white chalk with stumping ",
#   "support_materials": "gray laid paper",
#   "department": "Drawings",
#   "collection": "DR - French",
#   "type": "Drawing",
#   "measurements": "Sheet: 33.2 x 49.7 cm (13 1/16 x 19 9/16 in.)",
#   "state_of_the_work": "",
#   "edition_of_the_work": "",
#   "creditline": "Bequest of Muriel Butkin",
#   "copyright": "",
#   "inscriptions": "Verso: upper right in green ink: 80355 / circular estate stamp (Lugt 1664b) ",
#   "exhibitions": " **LEGACY: Exposition de Lebourg, Mus\u00e9e de Rouen, 1932",
#   "provenance": "",
#   "find_spot": "",
#   "related_works": "",
#   "former_accession_numbers": "[]",
#   "fun_fact": "",
#   "digital_description": "",
#   "wall_description": "",
#   "external_resources": "{'wikidata': [], 'internet_archive': ['https://archive.org/details/clevelandart-2015.449-a-miller-s-carriage']}",
#   "citations": "",
#   "catalogue_raisonne": "",
#   "url": "https://clevelandart.org/art/2015.449",
#   "image_web": "https://openaccess-cdn.clevelandart.org/2015.449/2015.449_web.jpg",
#   "image_print": "https://openaccess-cdn.clevelandart.org/2015.449/2015.449_print.jpg",
#   "image_full": "https://openaccess-cdn.clevelandart.org/2015.449/2015.449_full.tif",
#   "updated_at": "2021-06-29 06:35:50.572000"
# }

# %% [markdown]
# # Try with your own CSV file
#
# If you'd like to try this with your own CSV file, select the file on your local system using the widget below.
#
# The `ipywidgets` Python module will be used for the file upload.
#
# ### Further Reading
#
# https://ipywidgets.readthedocs.io/

# %%
try:
    import ipywidgets as widgets
except:
    # !pip install ipywidgets
    import ipywidgets as widgets
    
from ipywidgets import Layout, FileUpload 


try:
    import IPython
except:
    # %pip install IPython
    import IPython 
from IPython.display import display, IFrame, HTML, Javascript
from IPython.core.display import HTML


import io

# %% [markdown]
# ## Display file upload widget

# %%
# define file upload widget
uploader = widgets.FileUpload(accept='*.csv', multiple=False, description='Select CSV file')
uploader.style.button_color = 'orange'

display(uploader)
# Out:
# FileUpload(value={}, accept='*.csv', description='Select CSV file', style=ButtonStyle(button_color='orange'))

# %% [markdown]
# ## Read contents of CSV file
#
# The following code reads the contents of the CSV file uploaded using the FileUpload widge and loads it into a `pandas` dataframe
#
# ### Display file contents
#
# `dataframe.head()` displays the first 5 rows for illustration. Add a number in .head() to display more rows e.g. .head(20)

# %%
for filename in uploader.value:       
    if filename != ""  :  
        content = uploader.value[filename]["content"]

        # read file content into pandas dataframe
        dataframe = pd.read_csv(io.BytesIO(content))
        
       
        display(dataframe.head(50))
# Out:
#     Media     Object Number Department Classification  Culture  Period  \
# 0       0         64-1993-1        PDP       Drawings      NaN     NaN
# 1       1          1995-7-1        PDP       Drawings      NaN     NaN
# 2       0          9-1982-1         AA      Paintings      NaN     NaN
# 3       0         48-1993-1         AA      Paintings      NaN     NaN
# 4       0        250-2003-1         AA      Paintings      NaN     NaN
# 5       0  250-2003-1 frame         AA         Frames      NaN     NaN
# 6       0        250-2003-2         AA      Paintings      NaN     NaN
# 7       1         1942-12-1         AA      Paintings      NaN     NaN
# 8       1         1944-95-4         AA      Paintings      NaN     NaN
# 9       3       1949-18-109         AA      Paintings      NaN     NaN
# 10      3         1949-57-1         AA      Paintings      NaN     NaN
# 11      0         1967-38-1         AA      Paintings      NaN     NaN
# 12      1         1987-70-1         AA      Paintings      NaN     NaN
# 13      1         1987-70-2         AA      Paintings      NaN     NaN
# 14      4         1987-70-3         AA      Paintings      NaN     NaN
# 15      4         1987-70-4         AA      Paintings      NaN     NaN
# 16      2         1997-39-1        PDP       Drawings      NaN     NaN
# 17      1         1997-40-1        PDP       Drawings      NaN     NaN
# 18      2         1997-41-1        PDP       Drawings      NaN     NaN
# 19      2         1997-42-1        PDP       Drawings      NaN     NaN
# 20      1      2016-48-1(1)        PDP         Prints      NaN     NaN
# 21      1  2016-48-1(1--21)        PDP         Prints      NaN     NaN
# 22      1      2016-48-1(2)        PDP         Prints      NaN     NaN
# 23      1      2016-48-1(3)        PDP         Prints      NaN     NaN
# 24      1      2016-48-1(4)        PDP         Prints      NaN     NaN
# 25      1      2016-48-1(5)        PDP         Prints      NaN     NaN
# 26      1      2016-48-1(6)        PDP         Prints      NaN     NaN
# 27      1      2016-48-1(7)        PDP         Prints      NaN     NaN
# 28      1      2016-48-1(8)        PDP         Prints      NaN     NaN
# 29      1      2016-48-1(9)        PDP         Prints      NaN     NaN
# 30      1     2016-48-1(10)        PDP         Prints      NaN     NaN
# 31      1     2016-48-1(11)        PDP         Prints      NaN     NaN
# 32      1     2016-48-1(12)        PDP         Prints      NaN     NaN
# 33      1     2016-48-1(13)        PDP         Prints      NaN     NaN
# 34      1     2016-48-1(14)        PDP         Prints      NaN     NaN
# 35      1     2016-48-1(15)        PDP         Prints      NaN     NaN
# 36      1     2016-48-1(16)        PDP         Prints      NaN     NaN
# 37      1     2016-48-1(17)        PDP         Prints      NaN     NaN
# 38      1     2016-48-1(18)        PDP         Prints      NaN     NaN
# 39      1     2016-48-1(19)        PDP         Prints      NaN     NaN
# 40      1     2016-48-1(20)        PDP         Prints      NaN     NaN
# 41      1     2016-48-1(21)        PDP         Prints      NaN     NaN
# 42      4         2019-47-5        PDP       Drawings      NaN     NaN
# 43      1           AWC-125    SpecExh       Drawings      NaN     NaN
# 44      2           AWC-145    SpecExh       Drawings      NaN     NaN
# 45      1           AWC-153    SpecExh       Drawings      NaN     NaN
# 46      1           PSL-190    SpecExh      Paintings      NaN     NaN
# 47      1           PSL-221    SpecExh      Paintings      NaN     NaN
# 48      1           PSL-302    SpecExh      Paintings      NaN     NaN
# 49      0             testq        PDP         Prints      NaN     NaN
#
#         Display Name  Object Name  \
# 0        John Ruskin     Drawings
# 1        John Ruskin     Drawings
# 2   Georgia O'Keeffe    Paintings
# 3   Georgia O'Keeffe    Paintings
# 4   Georgia O'Keeffe    Paintings
# 5   Georgia O'Keeffe       Frames
# 6   Georgia O'Keeffe    Paintings
# 7   Georgia O'Keeffe    Paintings
# 8   Georgia O'Keeffe    Paintings
# 9   Georgia O'Keeffe    Paintings
# 10  Georgia O'Keeffe    Paintings
# 11  Georgia O'Keeffe    Paintings
# 12  Georgia O'Keeffe    Paintings
# 13  Georgia O'Keeffe    Paintings
# 14  Georgia O'Keeffe    Paintings
# 15  Georgia O'Keeffe    Paintings
# 16  Georgia O'Keeffe     Drawings
# 17  Georgia O'Keeffe     Drawings
# 18  Georgia O'Keeffe     Drawings
# 19  Georgia O'Keeffe     Drawings
# 20  Georgia O'Keeffe  Lithographs
# 21  Georgia O'Keeffe        Books
# 22  Georgia O'Keeffe  Lithographs
# 23  Georgia O'Keeffe  Lithographs
# 24  Georgia O'Keeffe  Lithographs
# 25  Georgia O'Keeffe  Lithographs
# 26  Georgia O'Keeffe  Lithographs
# 27  Georgia O'Keeffe  Lithographs
# 28  Georgia O'Keeffe  Lithographs
# 29  Georgia O'Keeffe  Lithographs
# 30  Georgia O'Keeffe  Lithographs
# 31  Georgia O'Keeffe  Lithographs
# 32  Georgia O'Keeffe  Lithographs
# 33  Georgia O'Keeffe  Lithographs
# 34  Georgia O'Keeffe  Lithographs
# 35  Georgia O'Keeffe  Lithographs
# 36  Georgia O'Keeffe  Lithographs
# 37  Georgia O'Keeffe  Lithographs
# 38  Georgia O'Keeffe  Lithographs
# 39  Georgia O'Keeffe  Lithographs
# 40  Georgia O'Keeffe  Lithographs
# 41  Georgia O'Keeffe  Lithographs
# 42  Georgia O'Keeffe     Drawings
# 43  Georgia O'Keeffe     Drawings
# 44  Georgia O'Keeffe     Drawings
# 45  Georgia O'Keeffe     Drawings
# 46  Georgia O'Keeffe    Paintings
# 47  Georgia O'Keeffe    Paintings
# 48  Georgia O'Keeffe    Paintings
# 49  Georgia O'Keeffe  Lithographs
#
#                                                 Title         Dated  ...  \
# 0             Study of a River Bank, Beauvais, France          1846  ...
# 1                                           Beanstalk  Date unknown  ...
# 2                              Mask with Golden Apple          1921  ...
# 3                              African Mask and Apple           NaN  ...
# 4               Red Hills with Pedernal, White Clouds          1936  ...
# 5    Frame for: Red Hills with Pedernal, White Clouds          1936  ...
# 6                              The Barns, Lake George          1926  ...
# 7                          White Petunias with Salvia           NaN  ...
# 8                                     Peach and Glass          1927  ...
# 9                                 Red Hills and Bones          1941  ...
# 10                              Three Small Rocks Big          1937  ...
# 11                       After a Walk Back of Mabel's          1929  ...
# 12                          Birch and Pine Tree No. 1          1925  ...
# 13                                From the Lake No. 3          1924  ...
# 14                              Red and Orange Streak          1919  ...
# 15                           Two Calla Lilies on Pink          1928  ...
# 16                                     No. 15 Special     1916-1917  ...
# 17                                     Special No. 40          1934  ...
# 18                        Untitled (Beauford Delaney)          1943  ...
# 19                                        Drawing III          1959  ...
# 20                                         Blue Lines          1974  ...
# 21       Some Memories of Drawings - Georgia O'Keeffe          1974  ...
# 22                                     Drawing No. 14          1974  ...
# 23                                     Abstraction IX          1974  ...
# 24                                      Drawing No. 8          1974  ...
# 25                                      Drawing No. 9          1974  ...
# 26                                     Drawing No. 15          1974  ...
# 27                                     Drawing No. 13          1974  ...
# 28                                            Drawing          1974  ...
# 29                                     Drawing No. 12          1974  ...
# 30                                     Drawing No. 17          1974  ...
# 31                       Eagle Claw and Bean Necklace          1974  ...
# 32                                     Drawing No. 40          1974  ...
# 33                                      Banana Flower          1974  ...
# 34                       The City (New York Rooftops)          1974  ...
# 35                                   Beauford Delaney          1974  ...
# 36                                    Goat's Horns II          1974  ...
# 37                                     Ram's Horns II          1974  ...
# 38                                          Drawing I          1974  ...
# 39                                        Drawing III          1974  ...
# 40                                     Antelope Horns          1974  ...
# 41                                    The Winter Road          1974  ...
# 42                                      Nude Series V          1918  ...
# 43                              Evening Star, No. III          1917  ...
# 44                               Evening Star, No. II          1917  ...
# 45                              Evening Star, No. VII          1917  ...
# 46                  Cow's Skull: Red, White, and Blue          1931  ...
# 47                                 Cow's Skull on Red     1931/1936  ...
# 48  From the Faraway, Nearby (Deer's Horns Near Ca...          1937  ...
# 49                                         Blue Lines          1974  ...
#
#    Unnamed: 16370 Unnamed: 16371  Unnamed: 16372 Unnamed: 16373  \
# 0             NaN            NaN             NaN            NaN
# 1             NaN            NaN             NaN            NaN
# 2             NaN            NaN             NaN            NaN
# 3             NaN            NaN             NaN            NaN
# 4             NaN            NaN             NaN            NaN
# 5             NaN            NaN             NaN            NaN
# 6             NaN            NaN             NaN            NaN
# 7             NaN            NaN             NaN            NaN
# 8             NaN            NaN             NaN            NaN
# 9             NaN            NaN             NaN            NaN
# 10            NaN            NaN             NaN            NaN
# 11            NaN            NaN             NaN            NaN
# 12            NaN            NaN             NaN            NaN
# 13            NaN            NaN             NaN            NaN
# 14            NaN            NaN             NaN            NaN
# 15            NaN            NaN             NaN            NaN
# 16            NaN            NaN             NaN            NaN
# 17            NaN            NaN             NaN            NaN
# 18            NaN            NaN             NaN            NaN
# 19            NaN            NaN             NaN            NaN
# 20            NaN            NaN             NaN            NaN
# 21            NaN            NaN             NaN            NaN
# 22            NaN            NaN             NaN            NaN
# 23            NaN            NaN             NaN            NaN
# 24            NaN            NaN             NaN            NaN
# 25            NaN            NaN             NaN            NaN
# 26            NaN            NaN             NaN            NaN
# 27            NaN            NaN             NaN            NaN
# 28            NaN            NaN             NaN            NaN
# 29            NaN            NaN             NaN            NaN
# 30            NaN            NaN             NaN            NaN
# 31            NaN            NaN             NaN            NaN
# 32            NaN            NaN             NaN            NaN
# 33            NaN            NaN             NaN            NaN
# 34            NaN            NaN             NaN            NaN
# 35            NaN            NaN             NaN            NaN
# 36            NaN            NaN             NaN            NaN
# 37            NaN            NaN             NaN            NaN
# 38            NaN            NaN             NaN            NaN
# 39            NaN            NaN             NaN            NaN
# 40            NaN            NaN             NaN            NaN
# 41            NaN            NaN             NaN            NaN
# 42            NaN            NaN             NaN            NaN
# 43            NaN            NaN             NaN            NaN
# 44            NaN            NaN             NaN            NaN
# 45            NaN            NaN             NaN            NaN
# 46            NaN            NaN             NaN            NaN
# 47            NaN            NaN             NaN            NaN
# 48            NaN            NaN             NaN            NaN
# 49            NaN            NaN             NaN            NaN
#
#    Unnamed: 16374 Unnamed: 16375  Unnamed: 16376  Unnamed: 16377  \
# 0             NaN            NaN             NaN             NaN
# 1             NaN            NaN             NaN             NaN
# 2             NaN            NaN             NaN             NaN
# 3             NaN            NaN             NaN             NaN
# 4             NaN            NaN             NaN             NaN
# 5             NaN            NaN             NaN             NaN
# 6             NaN            NaN             NaN             NaN
# 7             NaN            NaN             NaN             NaN
# 8             NaN            NaN             NaN             NaN
# 9             NaN            NaN             NaN             NaN
# 10            NaN            NaN             NaN             NaN
# 11            NaN            NaN             NaN             NaN
# 12            NaN            NaN             NaN             NaN
# 13            NaN            NaN             NaN             NaN
# 14            NaN            NaN             NaN             NaN
# 15            NaN            NaN             NaN             NaN
# 16            NaN            NaN             NaN             NaN
# 17            NaN            NaN             NaN             NaN
# 18            NaN            NaN             NaN             NaN
# 19            NaN            NaN             NaN             NaN
# 20            NaN            NaN             NaN             NaN
# 21            NaN            NaN             NaN             NaN
# 22            NaN            NaN             NaN             NaN
# 23            NaN            NaN             NaN             NaN
# 24            NaN            NaN             NaN             NaN
# 25            NaN            NaN             NaN             NaN
# 26            NaN            NaN             NaN             NaN
# 27            NaN            NaN             NaN             NaN
# 28            NaN            NaN             NaN             NaN
# 29            NaN            NaN             NaN             NaN
# 30            NaN            NaN             NaN             NaN
# 31            NaN            NaN             NaN             NaN
# 32            NaN            NaN             NaN             NaN
# 33            NaN            NaN             NaN             NaN
# 34            NaN            NaN             NaN             NaN
# 35            NaN            NaN             NaN             NaN
# 36            NaN            NaN             NaN             NaN
# 37            NaN            NaN             NaN             NaN
# 38            NaN            NaN             NaN             NaN
# 39            NaN            NaN             NaN             NaN
# 40            NaN            NaN             NaN             NaN
# 41            NaN            NaN             NaN             NaN
# 42            NaN            NaN             NaN             NaN
# 43            NaN            NaN             NaN             NaN
# 44            NaN            NaN             NaN             NaN
# 45            NaN            NaN             NaN             NaN
# 46            NaN            NaN             NaN             NaN
# 47            NaN            NaN             NaN             NaN
# 48            NaN            NaN             NaN             NaN
# 49            NaN            NaN             NaN             NaN
#
#     Unnamed: 16378  Unnamed: 16379
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19             NaN             NaN
# 20             NaN             NaN
# 21             NaN             NaN
# 22             NaN             NaN
# 23             NaN             NaN
# 24             NaN             NaN
# 25             NaN             NaN
# 26             NaN             NaN
# 27             NaN             NaN
# 28             NaN             NaN
# 29             NaN             NaN
# 30             NaN             NaN
# 31             NaN             NaN
# 32             NaN             NaN
# 33             NaN             NaN
# 34             NaN             NaN
# 35             NaN             NaN
# 36             NaN             NaN
# 37             NaN             NaN
# 38             NaN             NaN
# 39             NaN             NaN
# 40             NaN             NaN
# 41             NaN             NaN
# 42             NaN             NaN
# 43             NaN             NaN
# 44             NaN             NaN
# 45             NaN             NaN
# 46             NaN             NaN
# 47             NaN             NaN
# 48             NaN             NaN
# 49             NaN             NaN
#
# [50 rows x 16380 columns]
