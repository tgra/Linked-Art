# %% [markdown]
# # Extract Collection Data - JSON
#
# This notebook shows how to read in collection data in JSON format and convert it to a Python dictionary, ready for transformation to Linked Art.
#
# Steps in this notebook:
# 1. Read JSON file
# 2. Convert JSON file to Python Dictionary

# %% [markdown]
# # Python modules
#
#
# The following Python modules will be used:
# * json
#
#
# ## json
#
#
# The Python `json` module is used to encode and decode JSON objects and is used in the script to encode JSON objects before printing.
#
#
# ### Further Reading
#
# * https://docs.python.org/3/library/json.html

# %%
try:
    import json
except:
    # %pip install json
    import json

# %% [markdown]
# ## Read JSON file into Python dictionary
#
#
# The following code demonstrates how to read a JSON file and put contents into a `json` object using `json.load`.

# %%
file = '../data/rijks/json/nl-RP-T-1957-335.json'

# open file

with open(file) as json_file:
    
        # json.load() takes a file object and returns the json object
        obj = json.load(json_file)
        
        # for demonstration print json
        print(json.dumps(obj,indent=2))
# Out:
# {
#   "links": {
#     "self": "http://www.rijksmuseum.nl/api/nl/collection/RP-T-1957-335",
#     "web": "http://www.rijksmuseum.nl/nl/collectie/RP-T-1957-335"
#   },
#   "id": "nl-RP-T-1957-335",
#   "objectNumber": "RP-T-1957-335",
#   "title": "Gezicht op S. Anastasia te Verona, over de Adige",
#   "hasImage": true,
#   "principalOrFirstMaker": "John Ruskin",
#   "longTitle": "Gezicht op S. Anastasia te Verona, over de Adige, John Ruskin, 1829 - 1900",
#   "showImage": true,
#   "permitDownload": true,
#   "webImage": {
#     "guid": "c366d216-9aa1-4cb5-bbe5-fefa51f8e641",
#     "offsetPercentageX": 0,
#     "offsetPercentageY": 0,
#     "width": 2500,
#     "height": 1695,
#     "url": "https://lh3.googleusercontent.com/X0Xc5cER3eTrpNyqH4kg3ne-ewai_nBqFdSI-EZPZ4N-lE6rn1OAUBckEHQSFyafcGcFpiX99QU4STEXWbB43KsnAbi3=s0"
#   },
#   "headerImage": {
#     "guid": "84416aa1-5880-4751-ab94-72000580cd03",
#     "offsetPercentageX": 0,
#     "offsetPercentageY": 0,
#     "width": 1920,
#     "height": 460,
#     "url": "https://lh3.googleusercontent.com/LEfvA4m-B8Y6ty0tj8iC4epKOv1-VTT14KIY4NuLVnhsVHlpk4c3FHBJ6pkFpKN4dVmHQOpizc5JP3koX0okT34BwQ8=s0"
#   },
#   "productionPlaces": []
# }

# %% [markdown]
# # Try with your own JSON file
#
# If you'd like to try this with your own JSON file, select the file on your local system using the widget below.
#
# The `ipywidgets` Python module will be used for the file upload.
#
# ### Further Reading
#
# https://ipywidgets.readthedocs.io/

# %%
try:
    import ipywidgets as widgets
except:
    # !pip install ipywidgets
    import ipywidgets as widgets
    
from ipywidgets import Layout, FileUpload 


try:
    import IPython
except:
    # %pip install IPython
    import IPython 
from IPython.display import display, IFrame, HTML, Javascript
from IPython.core.display import HTML


import io

# %% [markdown]
# ## Display file upload widget

# %%
# define file upload widget
uploader = widgets.FileUpload(accept='*.json', multiple=False, description='Select JSON file')
uploader.style.button_color = 'orange'

display(uploader)
# Out:
# FileUpload(value={}, accept='*.json', description='Select JSON file', style=ButtonStyle(button_color='orange')…

# %% [markdown]
# ## Read contents of JSON file
#
# The following code reads the contents of the file uploaded using the FileUpload widget and loads it into a Python dictionary.
#
# ### Display file contents

# %%
for filename in uploader.value:       
    if filename != ""  :  
        content = uploader.value[filename]["content"]
        
        obj = json.load(io.BytesIO(content)) 

        print(json.dumps(obj,indent=2))
# Out:
# {
#   "objects": [
#     {
#       "1032": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/1032",
#         "type": "HumanMadeObject",
#         "_label": "long-neck vase with cup mouth",
#         "classified_as": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/stoneware",
#             "type": "Type",
#             "_label": "stoneware"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1032/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 1032,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "60.63",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/old-accession-number/1",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "TR5488/1",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "long-neck vase with cup mouth",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
#                 "type": "Type",
#                 "_label": "preferred terms"
#               }
#             ]
#           }
#         ],
#         "produced_by": {
#           "id": "https://data.discovernewfields.org/object/1032/production",
#           "type": "Production",
#           "_label": "Production of the Object",
#           "timespan": {
#             "id": "https://data.discovernewfields.org/object/1032/production/timespan",
#             "type": "TimeSpan",
#             "_label": "100-220",
#             "begin_of_the_begin": "0100-01-01T00:00:00.000Z",
#             "end_of_the_end": "0220-12-31T23:59:59.999Z"
#           }
#         },
#         "dimension": [
#           {
#             "id": "https://data.discovernewfields.org/object/1032/dimension-1/height",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 17.25,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055644",
#                 "type": "Type",
#                 "_label": "height"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           }
#         ],
#         "current_owner": {
#           "id": "http://vocab.getty.edu/ulan/500300517",
#           "type": "Group",
#           "_label": "Indianapolis Museum of Art at Newfields",
#           "classified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300312281",
#               "type": "Type",
#               "_label": "museums (institutions)"
#             }
#           ],
#           "acquired_title_through": [
#             {
#               "id": "https://data.discovernewfields.org/object/1032/IMA-acquisition",
#               "type": "Acquisition",
#               "_label": "IMA at Newfields Acquisition of the Object",
#               "classified_as": [
#                 {
#                   "id": "http://vocab.getty.edu/aat/300157782",
#                   "type": "Type",
#                   "_label": "acquisition (collections management)"
#                 }
#               ],
#               "took_place_at": [
#                 {
#                   "id": "http://vocab.getty.edu/tgn/7012924",
#                   "type": "Place",
#                   "_label": "Indianapolis, Indiana"
#                 }
#               ],
#               "timespan": {
#                 "id": "https://data.discovernewfields.org/object/1032/IMA-acquisition/timespan",
#                 "type": "TimeSpan",
#                 "_label": "1960-10-10",
#                 "begin_of_the_begin": "1960-10-10T00:00:00.000Z",
#                 "end_of_the_end": "1960-10-10T00:00:00.000Z"
#               }
#             }
#           ]
#         },
#         "member_of": [
#           {
#             "id": "https://data.discovernewfields.org/collection/9051",
#             "type": "Set",
#             "_label": "Collection of IMA at Newfields' Asian Art (Chinese and other Asian) Department",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300025976",
#                 "type": "Type",
#                 "_label": "collections (object groupings)"
#               }
#             ]
#           }
#         ],
#         "current_location": {
#           "id": "https://data.discovernewfields.org/thesauri/location/storage",
#           "type": "Place",
#           "_label": "IMA Storage"
#         },
#         "referred_to_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1032/credit-line",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "Gift of Mr. and Mrs. Eli Lilly",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/provenance-statement",
#             "type": "LinguisticObject",
#             "_label": "IMA Provenance Statement about the Object",
#             "content": "[Jan W. A. Kleijkamp]; Eli Lilly (May 1950 list noting Nov. 15, 1950 $950.); IMA (60.63)",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055863",
#                 "type": "Type",
#                 "_label": "provenance (history of ownership)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "17-1/4 in.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "stoneware, green glaze",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1032/rights-statement",
#             "type": "LinguisticObject",
#             "_label": "Rights Statement",
#             "content": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://creativecommons.org/publicdomain/mark/1.0/",
#             "type": "LinguisticObject",
#             "_label": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ],
#         "subject_of": [
#           {
#             "id": "http://collection.imamuseum.org/artwork/23059/",
#             "type": "LinguisticObject",
#             "_label": "Homepage for the Object",
#             "classified_as": [
#               {
#                 "id": "http://vocab/getty.edu/aat/300264578",
#                 "type": "Type",
#                 "_label": "Web pages (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300266277",
#                 "type": "Type",
#                 "_label": "home pages"
#               }
#             ],
#             "format": "text/html"
#           }
#         ]
#       }
#     },
#     {
#       "1065": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/1065",
#         "type": "HumanMadeObject",
#         "_label": "The Bachelor Boudoir (Corner of the Studio)",
#         "classified_as": [
#           {
#             "id": "http://vocab.getty.edu/aat/300133025",
#             "type": "Type",
#             "_label": "works of art"
#           },
#           {
#             "id": "http://vocab.getty.edu/aat/300033618",
#             "type": "Type",
#             "_label": "paintings (visual works)"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/paintings",
#             "type": "Type",
#             "_label": "paintings"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/oil-paintings",
#             "type": "Type",
#             "_label": "oil paintings"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1065/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 1065,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "14.55",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "The Bachelor Boudoir (Corner of the Studio)",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
#                 "type": "Type",
#                 "_label": "preferred terms"
#               }
#             ]
#           }
#         ],
#         "made_of": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/oil-paint",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "oil paint"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/canvas",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "canvas"
#           }
#         ],
#         "produced_by": {
#           "id": "https://data.discovernewfields.org/object/1065/production",
#           "type": "Production",
#           "_label": "Production of the Object",
#           "carried_out_by": [
#             {
#               "id": "https://data.discovernewfields.org/actor/1065",
#               "type": "Actor",
#               "_label": "Fiscus, Charles J."
#             }
#           ],
#           "timespan": {
#             "id": "https://data.discovernewfields.org/object/1065/production/timespan",
#             "type": "TimeSpan",
#             "_label": "about 1883",
#             "begin_of_the_begin": "1882-01-01T00:00:00.000Z",
#             "end_of_the_end": "1883-12-31T23:59:59.999Z"
#           }
#         },
#         "dimension": [
#           {
#             "id": "https://data.discovernewfields.org/object/1065/dimension-1/height",
#             "type": "Dimension",
#             "_label": "Unframed Dimensions of the Object",
#             "value": 27.25,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055644",
#                 "type": "Type",
#                 "_label": "height"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/dimension-1/width",
#             "type": "Dimension",
#             "_label": "Unframed Dimensions of the Object",
#             "value": 16.25,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055647",
#                 "type": "Type",
#                 "_label": "width"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           }
#         ],
#         "current_owner": {
#           "id": "http://vocab.getty.edu/ulan/500300517",
#           "type": "Group",
#           "_label": "Indianapolis Museum of Art at Newfields",
#           "classified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300312281",
#               "type": "Type",
#               "_label": "museums (institutions)"
#             }
#           ],
#           "acquired_title_through": [
#             {
#               "id": "https://data.discovernewfields.org/object/1065/IMA-acquisition",
#               "type": "Acquisition",
#               "_label": "IMA at Newfields Acquisition of the Object",
#               "classified_as": [
#                 {
#                   "id": "http://vocab.getty.edu/aat/300157782",
#                   "type": "Type",
#                   "_label": "acquisition (collections management)"
#                 }
#               ],
#               "took_place_at": [
#                 {
#                   "id": "http://vocab.getty.edu/tgn/7012924",
#                   "type": "Place",
#                   "_label": "Indianapolis, Indiana"
#                 }
#               ],
#               "timespan": {
#                 "id": "https://data.discovernewfields.org/object/1065/IMA-acquisition/timespan",
#                 "type": "TimeSpan",
#                 "_label": "1914-02-19",
#                 "begin_of_the_begin": "1914-02-19T00:00:00.000Z",
#                 "end_of_the_end": "1914-02-19T00:00:00.000Z"
#               }
#             }
#           ]
#         },
#         "member_of": [
#           {
#             "id": "https://data.discovernewfields.org/collection/9012",
#             "type": "Set",
#             "_label": "Collection of IMA at Newfields' American Painting and Sculpture 1800-1945 Department",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300025976",
#                 "type": "Type",
#                 "_label": "collections (object groupings)"
#               }
#             ]
#           }
#         ],
#         "current_location": {
#           "id": "https://data.discovernewfields.org/thesauri/location/westerley",
#           "type": "Place",
#           "_label": "Westerley"
#         },
#         "referred_to_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1065/credit-line",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "Gift of the Artist's mother, Mrs. E.J. Fiscus",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "27-1/4 x 16-1/4 in. (canvas)\n34-3/4 x 24-3/4 x 4 in. (framed)",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "oil on canvas",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/mark-description",
#             "type": "LinguisticObject",
#             "_label": "Mark Description of the Object",
#             "content": "Signed, l.r.: C FISCUS",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300028744",
#                 "type": "Type",
#                 "_label": "marks (symbols)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/creation-notes",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Creation Notes about the Object",
#             "content": "Keep \"Latest\" date as 1883, the year the painting was exhibited at the National Academy of Design.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300027200",
#                 "type": "Type",
#                 "_label": "notes (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1065/rights-statement",
#             "type": "LinguisticObject",
#             "_label": "Rights Statement",
#             "content": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://creativecommons.org/publicdomain/mark/1.0/",
#             "type": "LinguisticObject",
#             "_label": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ],
#         "part": [
#           {
#             "id": "https://data.discovernewfields.org/object/1065/frame-1",
#             "type": "HumanMadeObject",
#             "_label": "Frame for the Object",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300189814",
#                 "type": "Type",
#                 "_label": "frames (protective furnishings)"
#               }
#             ],
#             "dimension": [
#               {
#                 "id": "https://data.discovernewfields.org/object/1065/frame-1/height",
#                 "type": "Dimension",
#                 "_label": "Framed Dimensions of the Object",
#                 "value": 34.75,
#                 "classified_as": [
#                   {
#                     "id": "http://vocab.getty.edu/aat/300055644",
#                     "type": "Type",
#                     "_label": "height"
#                   }
#                 ],
#                 "unit": {
#                   "id": "http://vocab.getty.edu/aat/300379100",
#                   "type": "Type",
#                   "_label": "inches"
#                 }
#               },
#               {
#                 "id": "https://data.discovernewfields.org/object/1065/frame-1/width",
#                 "type": "Dimension",
#                 "_label": "Framed Dimensions of the Object",
#                 "value": 24.75,
#                 "classified_as": [
#                   {
#                     "id": "http://vocab.getty.edu/aat/300055647",
#                     "type": "Type",
#                     "_label": "width"
#                   }
#                 ],
#                 "unit": {
#                   "id": "http://vocab.getty.edu/aat/300379100",
#                   "type": "Type",
#                   "_label": "inches"
#                 }
#               },
#               {
#                 "id": "https://data.discovernewfields.org/object/1065/frame-1/depth",
#                 "type": "Dimension",
#                 "_label": "Framed Dimensions of the Object",
#                 "value": 4.0,
#                 "classified_as": [
#                   {
#                     "id": "http://vocab.getty.edu/aat/300072633",
#                     "type": "Type",
#                     "_label": "depth (size/dimension)"
#                   }
#                 ],
#                 "unit": {
#                   "id": "http://vocab.getty.edu/aat/300379100",
#                   "type": "Type",
#                   "_label": "inches"
#                 }
#               }
#             ]
#           }
#         ],
#         "subject_of": [
#           {
#             "id": "http://collection.imamuseum.org/artwork/56270/",
#             "type": "LinguisticObject",
#             "_label": "Homepage for the Object",
#             "classified_as": [
#               {
#                 "id": "http://vocab/getty.edu/aat/300264578",
#                 "type": "Type",
#                 "_label": "Web pages (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300266277",
#                 "type": "Type",
#                 "_label": "home pages"
#               }
#             ],
#             "format": "text/html"
#           }
#         ]
#       }
#     },
#     {
#       "1105": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/1105",
#         "type": "HumanMadeObject",
#         "_label": "bowl",
#         "classified_as": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/bowls",
#             "type": "Type",
#             "_label": "bowls"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1105/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 1105,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "1989.1569",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/old-accession-number/1",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "E84.43",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "bowl",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
#                 "type": "Type",
#                 "_label": "preferred terms"
#               }
#             ]
#           }
#         ],
#         "made_of": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/brass",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "brass"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/gold",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "gold"
#           }
#         ],
#         "produced_by": {
#           "id": "https://data.discovernewfields.org/object/1105/production",
#           "type": "Production",
#           "_label": "Production of the Object",
#           "carried_out_by": [
#             {
#               "id": "https://data.discovernewfields.org/thesauri/culture/benin-kingdom",
#               "type": "Actor",
#               "_label": "Benin Kingdom"
#             },
#             {
#               "id": "https://data.discovernewfields.org/thesauri/culture/edo-people",
#               "type": "Actor",
#               "_label": "Edo people"
#             }
#           ],
#           "timespan": {
#             "id": "https://data.discovernewfields.org/object/1105/production/timespan",
#             "type": "TimeSpan",
#             "_label": "late 19th century",
#             "begin_of_the_begin": "1850-01-01T00:00:00.000Z",
#             "end_of_the_end": "1897-12-31T23:59:59.999Z"
#           }
#         },
#         "dimension": [
#           {
#             "id": "https://data.discovernewfields.org/object/1105/dimension-1/height",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 9.0,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055644",
#                 "type": "Type",
#                 "_label": "height"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           }
#         ],
#         "current_owner": {
#           "id": "http://vocab.getty.edu/ulan/500300517",
#           "type": "Group",
#           "_label": "Indianapolis Museum of Art at Newfields",
#           "classified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300312281",
#               "type": "Type",
#               "_label": "museums (institutions)"
#             }
#           ],
#           "acquired_title_through": [
#             {
#               "id": "https://data.discovernewfields.org/object/1105/IMA-acquisition",
#               "type": "Acquisition",
#               "_label": "IMA at Newfields Acquisition of the Object",
#               "classified_as": [
#                 {
#                   "id": "http://vocab.getty.edu/aat/300157782",
#                   "type": "Type",
#                   "_label": "acquisition (collections management)"
#                 }
#               ],
#               "took_place_at": [
#                 {
#                   "id": "http://vocab.getty.edu/tgn/7012924",
#                   "type": "Place",
#                   "_label": "Indianapolis, Indiana"
#                 }
#               ]
#             }
#           ]
#         },
#         "member_of": [
#           {
#             "id": "https://data.discovernewfields.org/collection/9061",
#             "type": "Set",
#             "_label": "Collection of IMA at Newfields' African Art Department",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300025976",
#                 "type": "Type",
#                 "_label": "collections (object groupings)"
#               }
#             ]
#           }
#         ],
#         "current_location": {
#           "id": "https://data.discovernewfields.org/thesauri/location/W302",
#           "type": "Place",
#           "_label": "Eiteljorg Suite of African and Oceanic Art",
#           "clasified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300240057",
#               "type": "Type",
#               "_label": "galleries (display spaces)"
#             }
#           ]
#         },
#         "referred_to_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/1105/credit-line",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "Gift of Mr. and Mrs. Harrison Eiteljorg",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/provenance-statement",
#             "type": "LinguisticObject",
#             "_label": "IMA Provenance Statement about the Object",
#             "content": "(Christie's London) sold on June 25, 1984 to Harrison Eiteljorg [1903-1997] of Indianapolis; donated to the IMA 1989",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055863",
#                 "type": "Type",
#                 "_label": "provenance (history of ownership)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "9 in.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "brass with gold covering",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/1105/rights-statement",
#             "type": "LinguisticObject",
#             "_label": "Rights Statement",
#             "content": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://creativecommons.org/publicdomain/mark/1.0/",
#             "type": "LinguisticObject",
#             "_label": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ],
#         "subject_of": [
#           {
#             "id": "http://collection.imamuseum.org/artwork/29429/",
#             "type": "LinguisticObject",
#             "_label": "Homepage for the Object",
#             "classified_as": [
#               {
#                 "id": "http://vocab/getty.edu/aat/300264578",
#                 "type": "Type",
#                 "_label": "Web pages (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300266277",
#                 "type": "Type",
#                 "_label": "home pages"
#               }
#             ],
#             "format": "text/html"
#           }
#         ]
#       }
#     },
#     {
#       "3457": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/3457",
#         "type": "HumanMadeObject",
#         "_label": "basketry bowl",
#         "classified_as": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/containers",
#             "type": "Type",
#             "_label": "containers"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/baskets",
#             "type": "Type",
#             "_label": "baskets"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/bowls",
#             "type": "Type",
#             "_label": "bowls"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/3457/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 3457,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "U477",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "basketry bowl",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
#                 "type": "Type",
#                 "_label": "preferred terms"
#               }
#             ]
#           }
#         ],
#         "made_of": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/plant-fiber",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "plant fiber"
#           }
#         ],
#         "produced_by": {
#           "id": "https://data.discovernewfields.org/object/3457/production",
#           "type": "Production",
#           "_label": "Production of the Object",
#           "carried_out_by": [
#             {
#               "id": "https://data.discovernewfields.org/thesauri/culture/pima-people",
#               "type": "Actor",
#               "_label": "Pima people"
#             }
#           ],
#           "timespan": {
#             "id": "https://data.discovernewfields.org/object/3457/production/timespan",
#             "type": "TimeSpan",
#             "_label": "1900-1950",
#             "begin_of_the_begin": "1900-01-01T00:00:00.000Z",
#             "end_of_the_end": "1950-12-31T23:59:59.999Z"
#           }
#         },
#         "dimension": [
#           {
#             "id": "https://data.discovernewfields.org/object/3457/dimension-1/height",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 1.5,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055644",
#                 "type": "Type",
#                 "_label": "height"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/dimension-1/width",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 7.125,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055647",
#                 "type": "Type",
#                 "_label": "width"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/dimension-1/depth",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 7.125,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300072633",
#                 "type": "Type",
#                 "_label": "depth (size/dimension)"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           }
#         ],
#         "current_keeper": {
#           "id": "http://vocab.getty.edu/ulan/500300517",
#           "type": "Group",
#           "_label": "Indianapolis Museum of Art at Newfields",
#           "classified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300312281",
#               "type": "Type",
#               "_label": "museums (institutions)"
#             }
#           ]
#         },
#         "member_of": [
#           {
#             "id": "https://data.discovernewfields.org/collection/9062",
#             "type": "Set",
#             "_label": "Collection of IMA at Newfields' Native Arts of the Americas Department",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300025976",
#                 "type": "Type",
#                 "_label": "collections (object groupings)"
#               }
#             ]
#           }
#         ],
#         "current_location": {
#           "id": "https://data.discovernewfields.org/thesauri/location/storage",
#           "type": "Place",
#           "_label": "IMA Storage"
#         },
#         "referred_to_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/3457/credit-line",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "Museum Accession",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "1-1/2 x 7-1/8 x 7-1/8 in.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "plant fiber",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3457/description",
#             "type": "LinguisticObject",
#             "_label": "Description of the Object",
#             "content": "a small woven bowl with a simple decorative dark and light pattern",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300411780",
#                 "type": "Type",
#                 "_label": "descriptions (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ],
#         "subject_of": [
#           {
#             "id": "http://collection.imamuseum.org/artwork/22182/",
#             "type": "LinguisticObject",
#             "_label": "Homepage for the Object",
#             "classified_as": [
#               {
#                 "id": "http://vocab/getty.edu/aat/300264578",
#                 "type": "Type",
#                 "_label": "Web pages (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300266277",
#                 "type": "Type",
#                 "_label": "home pages"
#               }
#             ],
#             "format": "text/html"
#           }
#         ]
#       }
#     },
#     {
#       "3521": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/3521",
#         "type": "HumanMadeObject",
#         "_label": "Still Life with Flowerpot",
#         "classified_as": [
#           {
#             "id": "http://vocab.getty.edu/aat/300133025",
#             "type": "Type",
#             "_label": "works of art"
#           },
#           {
#             "id": "http://vocab.getty.edu/aat/300033618",
#             "type": "Type",
#             "_label": "paintings (visual works)"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/paintings",
#             "type": "Type",
#             "_label": "paintings"
#           },
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/oil-paintings",
#             "type": "Type",
#             "_label": "oil paintings"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/3521/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 3521,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3521/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "42.07",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3521/old-accession-number/1",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "TR1658/647",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/3521/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "Still Life with Flowerpot",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
# ...
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "John Herron Fund",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/92386/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "B) 4-1/8 x 4-1/2 x 5-1/2 in.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/92386/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "earthenware with multi-colored glaze, Awata ware",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/92386/description",
#             "type": "LinguisticObject",
#             "_label": "Description of the Object",
#             "content": "miniature, 2-story hut with front and back doors and design of flowering trees on sides and windows and fence on front.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300411780",
#                 "type": "Type",
#                 "_label": "descriptions (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/92386/rights-statement",
#             "type": "LinguisticObject",
#             "_label": "Rights Statement",
#             "content": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://creativecommons.org/publicdomain/mark/1.0/",
#             "type": "LinguisticObject",
#             "_label": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "93739": {
#         "@context": "https://linked.art/ns/v1/linked-art.json",
#         "id": "https://data.discovernewfields.org/object/93739",
#         "type": "HumanMadeObject",
#         "_label": "wall fountain",
#         "classified_as": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/type/fountains",
#             "type": "Type",
#             "_label": "fountains"
#           }
#         ],
#         "identified_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/93739/irn",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Collections Database Number for the Object",
#             "content": 93739,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404621",
#                 "type": "Type",
#                 "_label": "repository numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/object-number",
#             "type": "Identifier",
#             "_label": "IMA at Newfields Object Number for the Object",
#             "content": "73.131.6A",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300312355",
#                 "type": "Type",
#                 "_label": "accession numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/old-accession-number-1",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "TR9961/11",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/old-accession-number-2",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "U841A",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/old-accession-number-3",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "U841B",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/old-accession-number-4",
#             "type": "Identifier",
#             "_label": "Identifier Assigned to the Object by IMA at Newfields Prior to Acquisition",
#             "content": "U841C",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404626",
#                 "type": "Type",
#                 "_label": "identification numbers"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/title",
#             "type": "Name",
#             "_label": "Primary Title for the Object",
#             "content": "wall fountain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300404670",
#                 "type": "Type",
#                 "_label": "preferred terms"
#               }
#             ]
#           }
#         ],
#         "made_of": [
#           {
#             "id": "https://data.discovernewfields.org/thesauri/material/marble",
#             "type": "Material",
#             "_label": "Material of Which the Object is Composed",
#             "content": "marble"
#           }
#         ],
#         "produced_by": {
#           "id": "https://data.discovernewfields.org/object/93739/production",
#           "type": "Production",
#           "_label": "Production of the Object"
#         },
#         "dimension": [
#           {
#             "id": "https://data.discovernewfields.org/object/93739/dimension-1/height",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 32.0,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055644",
#                 "type": "Type",
#                 "_label": "height"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/dimension-1/width",
#             "type": "Dimension",
#             "_label": "Dimensions of the Object",
#             "value": 42.0,
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055647",
#                 "type": "Type",
#                 "_label": "width"
#               }
#             ],
#             "unit": {
#               "id": "http://vocab.getty.edu/aat/300379100",
#               "type": "Type",
#               "_label": "inches"
#             }
#           }
#         ],
#         "current_owner": {
#           "id": "http://vocab.getty.edu/ulan/500300517",
#           "type": "Group",
#           "_label": "Indianapolis Museum of Art at Newfields",
#           "classified_as": [
#             {
#               "id": "http://vocab.getty.edu/aat/300312281",
#               "type": "Type",
#               "_label": "museums (institutions)"
#             }
#           ],
#           "acquired_title_through": [
#             {
#               "id": "https://data.discovernewfields.org/object/93739/IMA-acquisition",
#               "type": "Acquisition",
#               "_label": "IMA at Newfields Acquisition of the Object",
#               "classified_as": [
#                 {
#                   "id": "http://vocab.getty.edu/aat/300157782",
#                   "type": "Type",
#                   "_label": "acquisition (collections management)"
#                 }
#               ],
#               "took_place_at": [
#                 {
#                   "id": "http://vocab.getty.edu/tgn/7012924",
#                   "type": "Place",
#                   "_label": "Indianapolis, Indiana"
#                 }
#               ],
#               "timespan": {
#                 "id": "https://data.discovernewfields.org/object/93739/IMA-acquisition/timespan",
#                 "type": "TimeSpan",
#                 "_label": "1973-12-27",
#                 "begin_of_the_begin": "1973-12-27T00:00:00.000Z",
#                 "end_of_the_end": "1973-12-27T00:00:00.000Z"
#               }
#             }
#           ]
#         },
#         "member_of": [
#           {
#             "id": "https://data.discovernewfields.org/collection/9031",
#             "type": "Set",
#             "_label": "Collection of IMA at Newfields' Decorative Arts Department",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300025976",
#                 "type": "Type",
#                 "_label": "collections (object groupings)"
#               }
#             ]
#           }
#         ],
#         "current_location": {
#           "id": "https://data.discovernewfields.org/thesauri/location/storage",
#           "type": "Place",
#           "_label": "IMA Storage"
#         },
#         "referred_to_by": [
#           {
#             "id": "https://data.discovernewfields.org/object/93739/credit-line",
#             "type": "LinguisticObject",
#             "_label": "IMA at Newfields Credit Line for the Object",
#             "content": "Gift of Mr. and Mrs. Gus Mascari",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300026687",
#                 "type": "Type",
#                 "_label": "acknowledgments"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/title-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Title(s) Associated with the Object",
#             "content": "A-D in four pieces",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300417212",
#                 "type": "Type",
#                 "_label": "title statements"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/dimension-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Dimensions of the Object",
#             "content": "32 x 42 in.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300266036",
#                 "type": "Type",
#                 "_label": "dimensions"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/materials-statement",
#             "type": "LinguisticObject",
#             "_label": "Notes about the Materials of Which the Object is Composed",
#             "content": "marble",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300010358",
#                 "type": "Type",
#                 "_label": "materials (substances)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/description",
#             "type": "LinguisticObject",
#             "_label": "Description of the Object",
#             "content": "four pieces per file.",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300411780",
#                 "type": "Type",
#                 "_label": "descriptions (documents)"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://data.discovernewfields.org/object/93739/rights-statement",
#             "type": "LinguisticObject",
#             "_label": "Rights Statement",
#             "content": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           },
#           {
#             "id": "https://creativecommons.org/publicdomain/mark/1.0/",
#             "type": "LinguisticObject",
#             "_label": "Public Domain",
#             "classified_as": [
#               {
#                 "id": "http://vocab.getty.edu/aat/300055547",
#                 "type": "Type",
#                 "_label": "legal concepts"
#               },
#               {
#                 "id": "http://vocab.getty.edu/aat/300418049",
#                 "type": "Type",
#                 "_label": "brief texts"
#               }
#             ]
#           }
#         ]
#       }
#     }
#   ]
# }
